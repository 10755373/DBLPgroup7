# %%
import pandas as pd


pd.read_csv("test_output.csv")
# Out:
#       Unnamed: 0                          key2                          key1  \
# 0              0             conf/him/Roller91       journals/cagd/RollerA09
# 1              1      conf/ipps/SterlingBRSB96         journals/cma/CaoZLN06
# 2              2        conf/prdc/CioccaKKKK04            conf/mcpr/IyerKL87
# 3              3  conf/iberamia/AguileraBCGM06       conf/jelia/AguileraGO94
# 4              4              conf/ai/FinkJH03      conf/swat/HershbergerS08
# ...          ...                           ...                           ...
# 7967        7967        conf/ifip/CarlsonBGM74  journals/ibmsj/WellerCGPWZ80
# 7968        7968        conf/bncod/NeumannHM06               conf/gi/MuthN89
# 7969        7969  conf/sigir/CreceliusKMNPSW08               conf/gi/MuthN89
# 7970        7970   journals/jasss/PrietulaCG03      journals/cmot/Prietula00
# 7971        7971        conf/mdm/DudkowskiMR06        conf/msn/DudkowskiMR07
#
#        _c0  label  partition  original_id  \
# ...

# %%
# Out:
# 22/03/11 16:19:15 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , key1, key2, label, partition
#  Schema: _c0, key1, key2, label, partition
# Expected: _c0 but found:
# CSV file: file:///home/bart2/uva/BD/project/pipeline/data/train.csv
# 22/03/11 16:19:15 WARN CSVHeaderChecker: CSV header does not conform to the schema.
#  Header: , pauthor, peditor, ptitle, pyear, paddress, ppublisher, pseries, pid, pkey, ptype_id, pjournal_id, pbooktitle_id, pjournalfull_id, pbooktitlefull_id, partition
#  Schema: _c0, pauthor, peditor, ptitle, pyear, paddress, ppublisher, pseries, pid, pkey, ptype_id, pjournal_id, pbooktitle_id, pjournalfull_id, pbooktitlefull_id, partition
# Expected: _c0 but found:
# CSV file: file:///home/bart2/uva/BD/project/pipeline/data/dblp/dblp-3.csv
# ...

# %%
a, (b, c) = (1, (1,2))
a, b, c
# Out:
# (1, 1, 2)
