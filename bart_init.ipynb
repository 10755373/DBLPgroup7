# %% [markdown]
# # Load csvs

# %%
import pandas as pd
from pandas import DataFrame as DF
import json

# %%
dfs = []
for i in range(1, 5):
 dfs.append(pd.read_csv(f"dblp/dblp-{i}.csv"))

df = pd.concat(dfs)
df = df.rename(columns={"Unnamed: 0": "id"})
train = pd.read_csv("dblp/train.csv")
merged = train.merge(df, left_on="key1", right_on="pkey").merge(df, left_on="key2", right_on="pkey")
merged["prediction"] = False
merged.loc[merged["id_x"] == merged["id_y"], "prediction"] = True


# accuracy
print(f'accuracy: {(merged.prediction == merged.label).mean()}')
# recall
print(f"recall: {merged[merged.label].prediction.mean()}")
# precision
print(f"recall: {merged[merged.prediction].label.mean()}")
len(df.index)
# Out:
# accuracy: 0.558705469141997
# recall: 0.8
# recall: 0.5362786745964316
#         id                                            pauthor  peditor  \
# 0        4  Jorge Semião|Juan J. Rodríguez-Andina|Fabian V...      NaN
# 1        7                                      Patrice Caire      NaN
# 2       10                         Sundeep B|Andrew Thangaraj      NaN
# 3       18                           Gerardo Pardo-Castellote      NaN
# 4       19  Ki-Hoon Lee|Kyu-Young Whang|Wook-Shin Han|Min-...      NaN
# ...    ...                                                ...      ...
# 4251  9975   Online bin packing with arbitrary release times.      NaN
# 4252  9978                    Chew Lim Tan|Henry Wai Kit Chia      NaN
# 4253  9981                 Sue Newell|Jacky Swan|Joseph Weiss      NaN
# 4254  9988  Martijn Hendriks|Barend van den Nieuwelaar|Fri...      NaN
# 4255  9990  Daniel J. Magenheimer|Liz Peters|Karl Pettis|D...      NaN
#
#                                                  ptitle  pyear  paddress  \
# 0     Improving the Tolerance of Pipeline Based Circ...  -2007       NaN
# 1     A Normative Multi-Agent Systems Approach to th...  -2007       NaN
# 2     Self-Orthogonality of q-Ary Images of qm-Ary C...   2007       NaN
# 3     OMG Data-Distribution Service: Architectural O...  -2003       NaN
# 4     Structural Consistency: Enabling XML Keyword S...   2009       NaN
# ...                                                 ...    ...       ...
# 4251                             Yongqiang Shi|Deshi Ye   2008       NaN
# 4252  Neural Logic Network Learning using Genetic Pr...   2001       NaN
# 4253        Project Management: Minitrack Introduction.   2004       NaN
# 4254  Model checker aided design of a controller for...  -2006       NaN
# 4255  Integer Multiplication and Division on the HP ...  -1987       NaN
#
#      ppublisher pseries      pid                            pkey  ptype_id  \
# 0           NaN     NaN   180843          conf/dft/SemiaoRVSTT07         1
# 1           NaN     NaN   162991           conf/dagstuhl/Caire07         2
# 2           NaN     NaN  2261406               journals/tit/BT07         0
# 3           NaN     NaN   349720  conf/icdcsw/Pardo-Castellote03         1
# 4           NaN     NaN  1922328     journals/corr/abs-0911-4329         3
# ...         ...     ...      ...                             ...       ...
# 4251        NaN     NaN  2245299             journals/tcs/ShiY08         0
# 4252        NaN     NaN   460233               conf/ijcai/TanC01         2
# 4253        NaN     NaN   289610           conf/hicss/NewellSW04         1
# 4254        NaN     NaN  2224414      journals/sttt/HendriksNV06         3
# 4255        NaN     NaN    62674    conf/asplos/MagenheimerPPZ87         2
#
#       pjournal_id  pbooktitle_id  pjournalfull_id  pbooktitlefull_id  \
# 0               0              4                0                  4
# 1               0              7                0                  7
# 2               2              9                2                  9
# 3               0             11                0                 11
# 4               5              5                5                  5
# ...           ...            ...              ...                ...
# 4251           12              5               12                  5
# 4252            0             71                0                 71
# 4253            0            295                0                295
# 4254          374              5              374                  5
# 4255            0           1562                0               1562
#
#       partition
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ...         ...
# 4251          4
# 4252          4
# 4253          4
# 4254          4
# 4255          4
#
# [17165 rows x 16 columns]

# %% [markdown]
# # Load jsons

# %%
def load_json_to_frame(filename):
    with open(filename) as f:
        return DF(json.load(f)).set_index("id")

title = load_json_to_frame("dblp/pbooktitle.json")
title_full = load_json_to_frame("dblp/pbooktitlefull.json")
journal = load_json_to_frame("dblp/pjournal.json")
journal_full = load_json_to_frame("dblp/pjournalfull.json")
source_type = load_json_to_frame("dblp/ptype.json")

def replace_id_with_value(df, id_to_value, id_col_name, value_col_name):
    if id_col_name not in df:
        # make this operation idempotent
        return df
    df = df.merge(id_to_value, how='left', left_on=id_col_name, right_on="id")
    df = df.rename(columns={"name": value_col_name})
    df = df.drop(columns=[id_col_name])
    return df

def drop_cols_with_all_nans(df):
    for col in df:
        if df[col].isna().all():
            print(f"dropping column {col} since it contains only nans.")
            df = df.drop(columns=[col])
    return df

df = replace_id_with_value(df, title, "pbooktitle_id", "book_title")
df = replace_id_with_value(df, title_full, "pbooktitlefull_id", "book_title_full")
df = replace_id_with_value(df, journal, "pjournal_id", "journal")
df = replace_id_with_value(df, journal_full, "pjournalfull_id", "journal_full")
df = replace_id_with_value(df, source_type, "ptype_id", "source_type")
df = drop_cols_with_all_nans(df)
df
# Out:
# dropping column peditor since it contains only nans.
# dropping column paddress since it contains only nans.
#          id                                            pauthor  \
# 0         4  Jorge Semião|Juan J. Rodríguez-Andina|Fabian V...
# 1         7                                      Patrice Caire
# 2        10                         Sundeep B|Andrew Thangaraj
# 3        18                           Gerardo Pardo-Castellote
# 4        19  Ki-Hoon Lee|Kyu-Young Whang|Wook-Shin Han|Min-...
# ...     ...                                                ...
# 17160  9975   Online bin packing with arbitrary release times.
# 17161  9978                    Chew Lim Tan|Henry Wai Kit Chia
# 17162  9981                 Sue Newell|Jacky Swan|Joseph Weiss
# 17163  9988  Martijn Hendriks|Barend van den Nieuwelaar|Fri...
# 17164  9990  Daniel J. Magenheimer|Liz Peters|Karl Pettis|D...
#
#                                                   ptitle  pyear ppublisher  \
# 0      Improving the Tolerance of Pipeline Based Circ...  -2007        NaN
# 1      A Normative Multi-Agent Systems Approach to th...  -2007        NaN
# 2      Self-Orthogonality of q-Ary Images of qm-Ary C...   2007        NaN
# 3      OMG Data-Distribution Service: Architectural O...  -2003        NaN
# 4      Structural Consistency: Enabling XML Keyword S...   2009        NaN
# ...                                                  ...    ...        ...
# 17160                             Yongqiang Shi|Deshi Ye   2008        NaN
# 17161  Neural Logic Network Learning using Genetic Pr...   2001        NaN
# 17162        Project Management: Minitrack Introduction.   2004        NaN
# 17163  Model checker aided design of a controller for...  -2006        NaN
# 17164  Integer Multiplication and Division on the HP ...  -1987        NaN
#
#       pseries      pid                            pkey  partition  \
# 0         NaN   180843          conf/dft/SemiaoRVSTT07          1
# 1         NaN   162991           conf/dagstuhl/Caire07          1
# 2         NaN  2261406               journals/tit/BT07          1
# 3         NaN   349720  conf/icdcsw/Pardo-Castellote03          1
# 4         NaN  1922328     journals/corr/abs-0911-4329          1
# ...       ...      ...                             ...        ...
# 17160     NaN  2245299             journals/tcs/ShiY08          4
# 17161     NaN   460233               conf/ijcai/TanC01          4
# 17162     NaN   289610           conf/hicss/NewellSW04          4
# 17163     NaN  2224414      journals/sttt/HendriksNV06          4
# 17164     NaN    62674    conf/asplos/MagenheimerPPZ87          4
#
#                           book_title  \
# 0                                DFT
# 1      Normative Multi-agent Systems
# 2                              WiMớb
# 3                    ICDCS Workshops
# 4                               None
# ...                              ...
# 17160                           None
# 17161                          IJCAI
# 17162                          HICSS
# 17163                           None
# 17164                         ÁSPLỚS
#
#                                          book_title_full  \
# 0                                                    nán
# 1                               Éúrớpéán Grid Cớnféréncé
# 2      ACM Symposium on Parallel Algorithms and Archi...
# 3              International Agent Technology Conference
# 4                                                Messung
# ...                                                  ...
# 17160                                            Messung
# 17161  inroads (ACM SIGCSE Bulletin)|ACM SIGCSE Bulletin
# 17162                     Grid and Cooperative Computing
# 17163                                            Messung
# 17164                                                NaN
#
#                                        journal  \
# 0                                         None
# 1                                         None
# 2      IEEE Transactions on Information Theory
# 3                                         None
# 4                                         CoRR
# ...                                        ...
# 17160                      Theor. Comput. Sci.
# 17161                                     None
# 17162                                     None
# 17163                                     STTT
# 17164                                     None
#
#                                             journal_full    source_type
# 0                                                   None  inproceedings
# 1                                                   None  inprớcéédings
# 2      International Journal of Ambient Computing and...        árticlé
# 3                                                   None  inproceedings
# 4      International Journal of Wireless Information ...        article
# ...                                                  ...            ...
# 17160      ACM Transactions on Computation Theory (TOCT)        árticlé
# 17161                                               None  inprớcéédings
# 17162                                               None  inproceedings
# 17163                                                NaN        article
# 17164                                               None  inprớcéédings
#
# [17165 rows x 14 columns]

# %%
# view = train.merge(df, left_on="key1", right_on="pkey").merge(df, left_on="key2", right_on="pkey")
# view = view.drop(columns=["Unnamed: 0","key1",	"key2"])
# view.sort_index(axis=1).to_csv("view.csv")

# %%
def swap_on_condition(df, cond, col1, col2):
    df = df.copy()
    df.loc[cond(df), [col1, col2]] = (
        df.loc[cond(df), [col2, col1]].values)
    return df




title_contains_pipe_cond = lambda df: df["ptitle"].str.contains("\|")
author_contains_pipe_cond = lambda df: df["pauthor"].str.contains("\|")
author_longer_than_title_cond = lambda df: df["pauthor"].str.len() > df["ptitle"].str.len()


condition = lambda df: title_contains_pipe_cond(df) | \
(~title_contains_pipe_cond(df) & ~author_contains_pipe_cond(df) & author_longer_than_title_cond(df))

df = swap_on_condition(df, condition, "pauthor", 'ptitle')
df
# Out:
#          id                                            pauthor  \
# 0         4  Jorge Semião|Juan J. Rodríguez-Andina|Fabian V...
# 1       854                                     Wei Zhang 0002
# 2      8474  Fengming Zhang|Young-Jun Lee|T. Kane|Luca Schi...
# 3      4914  Bing Qiu|Yvon Savaria|Meng Lu|Chunyan Wang|Cla...
# 4      5135              Hossein Asadi|Mehdi Baradaran Tahoori
# ...     ...                                                ...
# 10511  9051      Ian H. Witten|Alistair Moffat|Timothy C. Bell
# 10512  9951                                      Meike Klettke
# 10513  9581  Willem P. de Roever|Frank S. de Boer|Ulrich Ha...
# 10514   376  Constantinos Kotopoulos|Nikolay B. Likhanov|Ra...
# 10515   376                                   Ravi R. Mazumdar
#
#                                                   ptitle  pyear  \
# 0      Improving the Tolerance of Pipeline Based Circ...  -2007
# 1      Computing Cache Vulnerability to Transient Err...  -2005
# 2      A Digital and Wide Power Bandwidth H-Field Gen...   2003
# 3      Yield Modeling of a WSI Telecom Router Archite...  -2002
# 4      Soft Error Modeling and Protection for Sequent...  -2005
# ...                                                  ...    ...
# 10511  Managing Gigabytes: Compressing and Indexing D...   1999
# 10512  Akquisition von Integritätsbedingungen in Date...  -1998
# 10513  Concurrency Verification: Introduction to Comp...   2001
# 10514  Asymptotic Analysis of the GPS System Fed by H...   2001
# 10515  Performance Modeling, Loss Networks, and Stati...   2009
#
#                                 ppublisher  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 10511                      Morgan Kaufmann
# 10512  Infix Verlag, St. Augustin, Germany
# 10513           Cambridge University Press
# 10514                                  NaN
# 10515         Morgan & Claypool Publishers
#
#                                                 pseries      pid  \
# 0                                                   NaN   180843
# 1                                                   NaN   180734
# 2                                                   NaN   180743
# 3                                                   NaN   180593
# 4                                                   NaN   180280
# ...                                                 ...      ...
# 10511                                               NaN     2303
# 10512                                           DISDBIS     1772
# 10513  Cambridge Tracts in Theoretical Computer Science      529
# 10514                                               NaN   472490
# 10515      Synthesis Lectures on Communication Networks  2434112
#
#                                 pkey  partition  \
# 0             conf/dft/SemiaoRVSTT07          1
# 1                   conf/dft/Zhang05          1
# 2          conf/dft/ZhangLKSMKMLMP03          1
# 3                 conf/dft/QiuSLWT02          4
# 4                  conf/dft/AsadiT05          4
# ...                              ...        ...
# 10511            books/mk/WittenMB99          3
# 10512          books/infix/Klettke98          4
# 10513          books/cu/RoeverBH2001          1
# 10514    conf/infocom/KotopoulosLM01          2
# 10515  series/synthesis/2009Mazumdar          3
#
#                                               book_title  \
# 0                                                    DFT
# 1                                                    DFT
# 2                                                    DFT
# 3                                                    DFT
# 4                                                    DFT
# ...                                                  ...
# 10511                                               None
# 10512                                               None
# 10513                                                nán
# 10514                                            INFOCOM
# 10515  Performance Modeling, Loss Networks, and Stati...
#
#                                        book_title_full journal journal_full  \
# 0                                                  nán    None         None
# 1                                                  nán    None         None
# 2                                                  nán    None         None
# 3                                                  nán    None         None
# 4                                                  nán    None         None
# ...                                                ...     ...          ...
# 10511                                          Messung    None         None
# 10512                                          Messung    None         None
# 10513                                             None    None         None
# 10514                                        Languages    None         None
# 10515  International Conference on Broadband Networks     None         None
#
#          source_type
# 0      inproceedings
# 1      inproceedings
# 2      inproceedings
# 3      inproceedings
# 4      inproceedings
# ...              ...
# 10511           book
# 10512           book
# 10513           book
# 10514           bớớk
# 10515           bớớk
#
# [10516 rows x 14 columns]
